# %%
#Deployment phase
import pickle

# %%
#load the model
loaded_model = pickle.load(open('Finalized_model_Mul_linear.sav','rb'))
result=loaded_model.predict([[1234,345,4565,1,0]])  # This is the input, Here we can give 5 input.
# Out:
# C:\Users\Mani\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([[43994.79745873]])
