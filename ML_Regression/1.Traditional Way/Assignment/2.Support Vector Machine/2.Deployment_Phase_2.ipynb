# %%
#Deployment phase
import pickle

# %%
#load the model
loaded_model = pickle.load(open('Finalized_model_SVM_rbf.sav','rb'))
result=loaded_model.predict([[40,21.20,2,1,0]])  # This is the input, Here we can give 5 input.

# %%
result
# Out:
# array([16589.18908958])
