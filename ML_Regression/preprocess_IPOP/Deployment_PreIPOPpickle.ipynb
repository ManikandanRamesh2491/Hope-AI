# %%
#Deployment phase import pickle
import pickle

# %%
# Load trained model
sc = pickle.load(open("scaler_svr.sav", 'rb'))

# %%
# Scale input
preinput = sc.transform([[1300,12000,4000,0,1]])
# Out:
# C:\Users\Mani\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
preinput
# Out:
# array([[-1.46755405, -4.33835385, -1.50744257, -0.5       ,  1.30088727]])

# %%
#load the model
loaded_model=pickle.load(open("finalized_model_svr.sav",'rb'))
result=loaded_model.predict(preinput)

# %%
result
# Out:
# array([-1.03109284])

# %%
#preprocess output - used inverse_transform function to Scale back the data to the original representation
preoutput=sc.inverse_transform([result])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 2
#       1 #preprocess output - used inverse_transform function to Scale back the data to the original representation
# ----> 2 preoutput=sc.inverse_transform([result])
#
# File ~\anaconda3\Lib\site-packages\sklearn\preprocessing\_data.py:1139, in StandardScaler.inverse_transform(self, X, copy)
#    1137 else:
#    1138     if self.with_std:
# -> 1139         X *= self.scale_
#    1140     if self.with_mean:
#    1141         X += self.mean_
#
# ValueError: non-broadcastable output operand with shape (1,1) doesn't match the broadcast shape (1,5)

# %%
p
