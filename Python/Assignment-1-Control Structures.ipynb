# %%
print("Welcome to Assognment-1")
# Out:
# Welcome to Assognment-1

# %%
num1=10
num2=30
print("Num1=",num1)
print("Num2=",num2)
print("Add=",num1+num2)
# Out:
# Num1= 10
# Num2= 30
# Add= 40

# %%
#Body Mass Index

# %%
BMIValue=float(input("Enter the BMI Index:"))
if(BMIValue<18.5):
    print("Underweight")
elif(BMIValue<=24.9):
    print("Normal")
elif(BMIValue<=29.9):
    print("Overweight")
else:
    print("Obese")
# Out:
# Enter the BMI Index: 28
# Overweight
